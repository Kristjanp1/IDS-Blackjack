# %%
import pandas as pd

data = pd.read_csv("blkjckhands.csv", index_col=False)
# Out:
#         Unnamed: 0 PlayerNo  card1  card2  card3  card4  card5  sumofcards  \
# 0                0  Player1      7     10      0      0      0          17
# 1                1  Player2     10      9      0      0      0          19
# 2                2  Player3      9      8      0      0      0          17
# 3                3  Player4      2     10      0      5      0          17
# 4                4  Player5     10      2      0      5      0          17
# ...            ...      ...    ...    ...    ...    ...    ...         ...
# 899995           1  Player2     10      7      0      0      0          17
# 899996           2  Player3      6      1     10      0      0          17
# 899997           3  Player4      4      2      9      0      0          15
# 899998           4  Player5      9     10      0      0      0          19
# 899999           5  Player6      5     10      0      0      0          15
#
# ...

# %%
twocards = data[(data["card3"]==0) & (data["card5"]==0) & (data["card4"]==0)]
#twocards 
threecards = data[(data["card3"]!=0) & (data["card5"]==0) & (data["card4"]==0)]
fourcards = data[(data["card3"]!=0) & (data["card5"]==0) & (data["card4"]!=0)]
fivecards = data[(data["card3"]!=0) & (data["card5"]!=0) & (data["card4"]!=0)]
#fivecards

hardhands = twocards[(twoCards)]
# Out:
#         Unnamed: 0 PlayerNo  card1  card2  card3  card4  card5  sumofcards  \
# 73               1  Player2      2      2      4      3     10          21
# 75               3  Player4      2      4      2      3      1          12
# 83               5  Player6      2      2     10      1     10          25
# 190              4  Player5      4      5      2      3     10          24
# 256              4  Player5      2      9      4      1      1          17
# ...            ...      ...    ...    ...    ...    ...    ...         ...
# 899742           0  Player1      9      2      2      1     10          24
# 899756           2  Player3      8      3      1      2      7          21
# 899887           1  Player2      3      2      8      3     10          26
# 899926           4  Player5      2      4      4      4     10          24
# 899930           2  Player3      3      2      4      2      1          12
#
# ...
